# %%
from dotenv import load_dotenv
import os

load_dotenv()

api_key = os.getenv('OPENAI_API_KEY')
os.environ["OPENAI_API_KEY"] = api_key

# %% [markdown]
# ### LLMs

# %%
from langchain_openai import ChatOpenAI

llm = ChatOpenAI(model_name="gpt-4o", temperature=0)
result = llm.invoke('자기 소개를 해주세요.')
print(result)
# Out:
# content='안녕하세요! 저는 OpenAI에서 개발한 인공지능 언어 모델인 Assistant입니다. 다양한 주제에 대해 정보를 제공하고 질문에 답변할 수 있도록 설계되었습니다. 글쓰기, 번역, 정보 검색 등 여러 가지 작업을 도와드릴 수 있습니다. 궁금한 점이 있으면 언제든지 물어보세요!' additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 74, 'prompt_tokens': 14, 'total_tokens': 88, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_6ec83003ad', 'id': 'chatcmpl-BD7qLLN8eZEg6aBb2quMcE92vjwT1', 'finish_reason': 'stop', 'logprobs': None} id='run-67b81afe-c00f-49e4-b955-2c6f0eaec4fe-0' usage_metadata={'input_tokens': 14, 'output_tokens': 74, 'total_tokens': 88, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}

# %% [markdown]
# ### Chat models

# %%
from langchain_openai import ChatOpenAI
from langchain.schema import AIMessage, HumanMessage, SystemMessage

chat = ChatOpenAI(model_name='gpt-4o', temperature=0)
messages =[
  SystemMessage(content='yor are a helpful assistant'),
  HumanMessage(content='안녕하세요! 저는 민호 라고 합니다.'),
  AIMessage(content='안녕하세요 민호씨! 어떻게 도와드릴까요?'),
  HumanMessage(content="내 이름 아세요?")
]

result = chat.invoke(messages)
print(result.content)
# Out:
# 네, 방금 소개해주셔서 민호씨라는 것을 알게 되었습니다. 다른 질문이나 도움이 필요하시면 언제든지 말씀해 주세요!
