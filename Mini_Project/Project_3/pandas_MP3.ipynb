# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
#주피터에서 실행결과 여러줄 보여주고싶을때
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"
import squarify

# %%
#폰트 확인

import matplotlib.font_manager as fm
fontlist = fm.findSystemFonts(fontpaths=None, fontext='ttf')

f = [f.name for f in fm.fontManager.ttflist]
print(f'{f} \n')

# 한글 폰트 경로 설정 (예: 맑은 고딕)
font_path = r'C:\Windows\Fonts\malgun.ttf'  # Windows 기준
font_prop = fm.FontProperties(fname=font_path)

# 폰트 설정 적용
plt.rcParams['font.family'] = font_prop.get_name()
# Out:
# ['cmsy10', 'cmr10', 'DejaVu Sans', 'cmex10', 'STIXSizeThreeSym', 'DejaVu Sans Display', 'DejaVu Sans Mono', 'DejaVu Serif', 'STIXSizeThreeSym', 'STIXSizeTwoSym', 'STIXSizeTwoSym', 'DejaVu Sans', 'STIXSizeFourSym', 'cmtt10', 'STIXNonUnicode', 'DejaVu Sans Mono', 'cmmi10', 'STIXGeneral', 'DejaVu Serif', 'DejaVu Serif Display', 'DejaVu Sans', 'STIXSizeFourSym', 'STIXNonUnicode', 'STIXNonUnicode', 'cmss10', 'DejaVu Sans Mono', 'DejaVu Sans Mono', 'STIXSizeOneSym', 'DejaVu Serif', 'STIXGeneral', 'DejaVu Serif', 'DejaVu Sans', 'STIXSizeOneSym', 'STIXGeneral', 'STIXGeneral', 'STIXSizeFiveSym', 'cmb10', 'STIXNonUnicode', 'SimSun', 'Georgia', 'Harlow Solid Italic', 'Tw Cen MT Condensed', 'Candara', 'Tw Cen MT', 'Segoe UI', 'Bernard MT Condensed', 'MS Reference Sans Serif', 'Calisto MT', 'Arial', 'HCR Dotum Ext', 'Informal Roman', 'Palatino Linotype', 'Freestyle Script', 'Segoe Fluent Icons', 'Arial', 'Leelawadee UI', 'Book Antiqua', 'Arial', 'Material Design Icons', 'Californian FB', 'Georgia', 'Microsoft PhagsPa', 'Book Antiqua', 'Microsoft Uighur', 'Calisto MT', 'Goudy Old Style', 'HCR Dotum', 'Book Antiqua', 'Microsoft Uighur', 'Tempus Sans ITC', 'Gill Sans Ultra Bold', 'Calibri', 'Maiandra GD', 'Blackadder ITC', 'Vivaldi', 'Garamond', 'Wingdings', 'Lucida Sans', 'Lucida Console', 'Lucida Fax', 'Gulim', 'Lucida Sans Typewriter', 'Segoe UI', 'Microsoft YaHei', 'Eras Demi ITC', 'Wide Latin', 'Javanese Text', 'Segoe UI', 'Rockwell', 'Webdings', 'Century', 'Yu Gothic', 'Californian FB', 'HYPMokGak-Bold', 'Corbel', 'Rockwell', 'Palatino Linotype', 'Monotype Corsiva', 'Cambria', 'HCR Dotum', 'Bodoni MT', 'Candara', 'Constantia', 'Franklin Gothic Medium', 'MV Boli', 'HYGothic-Medium', 'Segoe UI', 'Gadugi', 'Calibri', 'Script MT Bold', 'Gill Sans MT', 'Segoe UI', 'Bodoni MT', 'Century Schoolbook', 'Bradley Hand ITC', 'Gill Sans MT Condensed', 'Nirmala UI', 'Bodoni MT', 'Malgun Gothic', 'Leelawadee UI', 'Candara', 'Cambria', 'Yu Gothic', 'Sans Serif Collection', 'Franklin Gothic Book', 'HYShortSamul-Medium', 'Segoe UI Emoji', 'Lucida Sans', 'MT Extra', 'Lucida Sans Typewriter', 'Colonna MT', 'SimSun-ExtB', 'Bodoni MT', 'Segoe MDL2 Assets', 'Agency FB', 'Gigi', 'Agency FB', 'Franklin Gothic Heavy', 'Tahoma', 'Corbel', 'Imprint MT Shadow', 'Segoe UI Variable', 'Onyx', 'Centaur', 'Footlight MT Light', 'Papyrus', 'Pyunji R', 'Bookman Old Style', 'Eras Bold ITC', 'Rockwell Condensed', 'Goudy Old Style', 'Calisto MT', 'Comic Sans MS', 'Times New Roman', 'Lucida Sans Typewriter', 'Nirmala UI', 'Parchment', 'Lucida Handwriting', 'Century Schoolbook', 'Material Design Icons 5.9.55', 'Courier New', 'Bodoni MT', 'Phosphor', 'Trebuchet MS', 'Harrington', 'Hancom Gothic', 'Old English Text MT', 'Niagara Solid', 'Haan Wing2', 'NewJumja', 'HYSinMyeongJo-Medium', 'Berlin Sans FB', 'OCR A Extended', 'HYMyeongJo-Extra', 'Segoe UI', 'Franklin Gothic Demi', 'Courier New', 'Cooper Black', 'Malgun Gothic', 'Microsoft YaHei', 'Mongolian Baiti', 'Arial', 'Bookman Old Style', 'Arial', 'MS Reference Specialty', 'Leelawadee', 'Gill Sans MT Ext Condensed Bold', 'Bauhaus 93', 'Tw Cen MT Condensed', 'Viner Hand ITC', 'Lucida Fax', 'Kunstler Script', 'Arial', 'HYGungSo-Bold', 'Consolas', 'Century Gothic', 'Cambria', 'Times New Roman', 'Brush Script MT', 'Arial Rounded MT Bold', 'Calisto MT', 'Segoe UI Symbol', 'Wingdings 3', 'Comic Sans MS', 'Perpetua', 'Microsoft JhengHei', 'Mistral', 'Lucida Bright', 'Segoe UI Historic', 'Palace Script MT', 'HyhwpEQ', 'Microsoft New Tai Lue', 'Chiller', 'HYGraphic-Medium', 'Californian FB', 'Niagara Engraved', 'Leelawadee UI', 'High Tower Text', 'Showcard Gothic', 'Engravers MT', 'remixicon', 'Magic R', 'Rockwell', 'Segoe UI', 'Leelawadee', 'Candara', 'Yet R', 'Verdana', 'New Gulim', 'Bell MT', 'Trebuchet MS', 'Bahnschrift', 'Lucida Calligraphy', 'elusiveicons', 'Sitka', 'Microsoft Himalaya', 'Garamond', 'Tw Cen MT', 'Edwardian Script ITC', 'Gill Sans MT', 'Haettenschweiler', 'Eras Medium ITC', 'Gill Sans Ultra Bold Condensed', 'Segoe U ...

# %%
df =pd.read_csv('./서울특별시_일반음식점.csv', sep=',', encoding='cp949')
df.head(10)
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_7200\3397017031.py:1: DtypeWarning: Columns (22,27,39,41,44,45) have mixed types. Specify dtype option on import or set low_memory=False.
#   df =pd.read_csv('./서울특별시_일반음식점.csv', sep=',', encoding='cp949')
#    번호 개방서비스명    개방서비스아이디  개방자치단체코드                    관리번호     인허가일자  인허가취소일자  \
# 0   1  일반음식점  07_24_04_P   3150000  3150000-101-2020-00448  20200803      NaN
# 1   2  일반음식점  07_24_04_P   3150000  3150000-101-2020-00449  20200803      NaN
# 2   3  일반음식점  07_24_04_P   3220000  3220000-101-2020-00851  20200803      NaN
# 3   4  일반음식점  07_24_04_P   3220000  3220000-101-2020-00853  20200803      NaN
# 4   5  일반음식점  07_24_04_P   3220000  3220000-101-2020-00855  20200803      NaN
# 5   6  일반음식점  07_24_04_P   3220000  3220000-101-2020-00856  20200803      NaN
# 6   7  일반음식점  07_24_04_P   3040000  3040000-101-2020-00273  20200803      NaN
# 7   8  일반음식점  07_24_04_P   3040000  3040000-101-2020-00276  20200803      NaN
# 8   9  일반음식점  07_24_04_P   3110000  3110000-101-2020-00280  20200803      NaN
# 9  10  일반음식점  07_24_04_P   3110000  3110000-101-2020-00281  20200803      NaN
#
#    영업상태구분코드  영업상태명  상세영업상태코드  ... 공장생산직종업원수  건물소유구분명  보증액  월세액  다중이용업소여부  \
# 0         1  영업/정상         1  ...       NaN      NaN  NaN  NaN         N
# 1         1  영업/정상         1  ...       NaN      NaN  NaN  NaN         N
# 2         1  영업/정상         1  ...       0.0      NaN  0.0  0.0         N
# 3         1  영업/정상         1  ...       NaN      NaN  NaN  NaN         Y
# 4         1  영업/정상         1  ...       NaN      NaN  NaN  NaN         N
# 5         1  영업/정상         1  ...       NaN      NaN  NaN  NaN         Y
# 6         1  영업/정상         1  ...       NaN      NaN  NaN  NaN         N
# 7         1  영업/정상         1  ...       NaN      NaN  NaN  NaN         N
# 8         1  영업/정상         1  ...       NaN      NaN  NaN  NaN         N
# 9         1  영업/정상         1  ...       NaN      NaN  NaN  NaN         N
#
#     시설총규모 전통업소지정번호  전통업소주된음식 홈페이지 Unnamed: 47
# 0   35.19      NaN       NaN  NaN         NaN
# 1   50.37      NaN       NaN  NaN         NaN
# 2   13.65      NaN       NaN  NaN         NaN
# 3  123.30      NaN       NaN  NaN         NaN
# 4    8.26      NaN       NaN  NaN         NaN
# 5  115.00      NaN       NaN  NaN         NaN
# 6   15.39      NaN       NaN  NaN         NaN
# 7  112.91      NaN       NaN  NaN         NaN
# 8   40.00      NaN       NaN  NaN         NaN
# 9   63.44      NaN       NaN  NaN         NaN
#
# [10 rows x 48 columns]

# %%
#서대문구 치킨집 개수 트리맵으로
#파이그래프,히트맵,막대그래프, 히트맵 등 다양하게
#치킨집 분포 확인하는게 목표

# %%
df['사업장명'],
df[df['업태구분명']=='호프/통닭'].head()
df[df['업태구분명']=='통닭(치킨)'].head()
# Out:
# (0                   혼밥대왕 마곡점
#  1                꾸어가게생선구이화곡점
#  2                      인생갈비탕
#  3                놀부 공유주방 선릉역
#  4                        온기정
#                   ...
#  472910      샐러드랩 샐랩 춘하추동프로젝트
#  472911                  노지푸드
#  472912    포베이키친밸리논현2호점 주방22호
#  472913                개성진 만두
#  472914                  동행포차
#  Name: 사업장명, Length: 472915, dtype: object,)
#     번호 개방서비스명    개방서비스아이디  개방자치단체코드                    관리번호     인허가일자  \
# 30  31  일반음식점  07_24_04_P   3110000  3110000-101-1999-06737  19991113
# 43  44  일반음식점  07_24_04_P   3180000  3180000-101-2001-14282  20010818
# 44  45  일반음식점  07_24_04_P   3010000  3010000-101-2001-13779  20010521
# 66  67  일반음식점  07_24_04_P   3000000  3000000-101-2002-11870  20020205
# 67  68  일반음식점  07_24_04_P   3210000  3210000-101-2000-15274  20001201
#
#     인허가취소일자  영업상태구분코드  영업상태명  상세영업상태코드  ... 공장생산직종업원수  건물소유구분명  보증액  월세액  \
# 30      NaN         1  영업/정상         1  ...       NaN      NaN  NaN  NaN
# 43      NaN         1  영업/정상         1  ...       0.0      NaN  0.0  0.0
# 44      NaN         1  영업/정상         1  ...       NaN      NaN  NaN  NaN
# 66      NaN         1  영업/정상         1  ...       NaN      NaN  NaN  NaN
# 67      NaN         1  영업/정상         1  ...       NaN      NaN  NaN  NaN
#
#     다중이용업소여부  시설총규모 전통업소지정번호  전통업소주된음식 홈페이지 Unnamed: 47
# 30         N  60.28      NaN       NaN  NaN         NaN
# 43         N  12.00      NaN       NaN  NaN         NaN
# 44         N  28.60      NaN       NaN  NaN         NaN
# 66         N  41.87      NaN       NaN  NaN         NaN
# 67         N  19.80      NaN       NaN  NaN         NaN
#
# [5 rows x 48 columns]
#       번호 개방서비스명    개방서비스아이디  개방자치단체코드                    관리번호     인허가일자  \
# 178  179  일반음식점  07_24_04_P   3120000  3120000-101-1997-05915  19970217
# 241  242  일반음식점  07_24_04_P   3110000  3110000-101-2014-00038  20140224
# 270  271  일반음식점  07_24_04_P   3110000  3110000-101-2014-00321  20141021
# 302  303  일반음식점  07_24_04_P   3110000  3110000-101-1999-06735  19991113
# 384  385  일반음식점  07_24_04_P   3110000  3110000-101-2001-07849  20010409
#
#      인허가취소일자  영업상태구분코드  영업상태명  상세영업상태코드  ... 공장생산직종업원수  건물소유구분명  보증액  월세액  \
# 178      NaN         1  영업/정상         1  ...       NaN      NaN  NaN  NaN
# 241      NaN         1  영업/정상         1  ...       NaN      NaN  NaN  NaN
# 270      NaN         1  영업/정상         1  ...       NaN      NaN  NaN  NaN
# 302      NaN         1  영업/정상         1  ...       NaN      NaN  NaN  NaN
# 384      NaN         1  영업/정상         1  ...       NaN      NaN  NaN  NaN
#
#      다중이용업소여부   시설총규모 전통업소지정번호  전통업소주된음식 홈페이지 Unnamed: 47
# 178         N  147.90      NaN       NaN  NaN         NaN
# 241         N   58.55      NaN       NaN  NaN         NaN
# 270         N   85.80      NaN       NaN  NaN         NaN
# 302         N   23.95      NaN       NaN  NaN         NaN
# 384         N   39.60      NaN       NaN  NaN         NaN
#
# [5 rows x 48 columns]

# %%
chicken_w = df.loc[df['영업상태구분코드']==1 & df['업태구분명'].isin(['호프/통닭','통닭(치킨)'])]
chicken_w= chicken_w.reset_index(drop=True, names='index')
chicken_w.drop('번호', axis=1,inplace=True)

# %%
#업태구분명이 호프/통닭 이거나 통닭(치킨)이고 현재 영업중인 영업상태 1인 가게들
chicken_w.head()
# Out:
#   개방서비스명    개방서비스아이디  개방자치단체코드                    관리번호     인허가일자  인허가취소일자  \
# 0  일반음식점  07_24_04_P   3110000  3110000-101-1999-06737  19991113      NaN
# 1  일반음식점  07_24_04_P   3180000  3180000-101-2001-14282  20010818      NaN
# 2  일반음식점  07_24_04_P   3010000  3010000-101-2001-13779  20010521      NaN
# 3  일반음식점  07_24_04_P   3000000  3000000-101-2002-11870  20020205      NaN
# 4  일반음식점  07_24_04_P   3210000  3210000-101-2000-15274  20001201      NaN
#
#    영업상태구분코드  영업상태명  상세영업상태코드 상세영업상태명  ...  공장생산직종업원수  건물소유구분명  보증액  월세액  \
# 0         1  영업/정상         1      영업  ...        NaN      NaN  NaN  NaN
# 1         1  영업/정상         1      영업  ...        0.0      NaN  0.0  0.0
# 2         1  영업/정상         1      영업  ...        NaN      NaN  NaN  NaN
# 3         1  영업/정상         1      영업  ...        NaN      NaN  NaN  NaN
# 4         1  영업/정상         1      영업  ...        NaN      NaN  NaN  NaN
#
#   다중이용업소여부  시설총규모  전통업소지정번호 전통업소주된음식 홈페이지  Unnamed: 47
# 0        N  60.28       NaN      NaN  NaN          NaN
# 1        N  12.00       NaN      NaN  NaN          NaN
# 2        N  28.60       NaN      NaN  NaN          NaN
# 3        N  41.87       NaN      NaN  NaN          NaN
# 4        N  19.80       NaN      NaN  NaN          NaN
#
# [5 rows x 47 columns]

# %%
chicken_w['소재지전체주소']  = chicken_w['소재지전체주소'].fillna(chicken_w['도로명전체주소'])
chicken_w['소재지전체주소'].isnull().sum()
# Out:
# 0

# %%
chicken_w
# Out:
#       개방서비스명    개방서비스아이디  개방자치단체코드                    관리번호     인허가일자  인허가취소일자  \
# 0      일반음식점  07_24_04_P   3110000  3110000-101-1999-06737  19991113      NaN
# 1      일반음식점  07_24_04_P   3180000  3180000-101-2001-14282  20010818      NaN
# 2      일반음식점  07_24_04_P   3010000  3010000-101-2001-13779  20010521      NaN
# 3      일반음식점  07_24_04_P   3000000  3000000-101-2002-11870  20020205      NaN
# 4      일반음식점  07_24_04_P   3210000  3210000-101-2000-15274  20001201      NaN
# ...      ...         ...       ...                     ...       ...      ...
# 13105  일반음식점  07_24_04_P   3120000  3120000-101-2021-00031  20210122      NaN
# 13106  일반음식점  07_24_04_P   3160000  3160000-101-2020-00384  20201208      NaN
# 13107  일반음식점  07_24_04_P   3200000  3200000-101-2020-00626  20201209      NaN
# 13108  일반음식점  07_24_04_P   3060000  3060000-101-2021-00028  20210203      NaN
# 13109  일반음식점  07_24_04_P   3080000  3080000-101-2021-00015  20210122      NaN
#
#        영업상태구분코드  영업상태명  상세영업상태코드 상세영업상태명  ...  공장생산직종업원수  건물소유구분명  보증액  월세액  \
# 0             1  영업/정상         1      영업  ...        NaN      NaN  NaN  NaN
# 1             1  영업/정상         1      영업  ...        0.0      NaN  0.0  0.0
# 2             1  영업/정상         1      영업  ...        NaN      NaN  NaN  NaN
# 3             1  영업/정상         1      영업  ...        NaN      NaN  NaN  NaN
# 4             1  영업/정상         1      영업  ...        NaN      NaN  NaN  NaN
# ...         ...    ...       ...     ...  ...        ...      ...  ...  ...
# 13105         1  영업/정상         1      영업  ...        NaN      NaN  NaN  NaN
# 13106         1  영업/정상         1      영업  ...        NaN      NaN  NaN  NaN
# 13107         1  영업/정상         1      영업  ...        NaN      NaN  NaN  NaN
# 13108         1  영업/정상         1      영업  ...        NaN      NaN  NaN  NaN
# 13109         1  영업/정상         1      영업  ...        NaN      NaN  NaN  NaN
#
#       다중이용업소여부  시설총규모  전통업소지정번호 전통업소주된음식 홈페이지  Unnamed: 47
# 0            N  60.28       NaN      NaN  NaN          NaN
# 1            N  12.00       NaN      NaN  NaN          NaN
# 2            N  28.60       NaN      NaN  NaN          NaN
# 3            N  41.87       NaN      NaN  NaN          NaN
# 4            N  19.80       NaN      NaN  NaN          NaN
# ...        ...    ...       ...      ...  ...          ...
# 13105        N  49.34       NaN      NaN  NaN          NaN
# 13106        N  33.00       NaN      NaN  NaN          NaN
# 13107        N  62.80       NaN      NaN  NaN          NaN
# 13108        N  53.84       NaN      NaN  NaN          NaN
# 13109        N  40.00       NaN      NaN  NaN          NaN
#
# [13110 rows x 47 columns]

# %%
f_add =chicken_w['소재지전체주소'].values.tolist()

gu=[]
dong=[]
for i in f_add:
  gu.append(i.split(sep=' ')[1])
  
for i in f_add:
  dong.append(i.split(sep=' ')[2])

# %%
chicken_w['지역구'] = gu
chicken_w['동이름'] = dong
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_7200\3708803159.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   chicken_w['지역구'] = gu
# C:\Users\user\AppData\Local\Temp\ipykernel_7200\3708803159.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   chicken_w['동이름'] = dong

# %%
dong
# Out:
# ['창천동',
#  '홍제동',
#  '남가좌동',
#  '연희동',
#  '창천동',
#  '연희동',
#  '창천동',
#  '남가좌동',
#  '북가좌동',
#  '북아현동',
#  '창천동',
#  '창천동',
#  '창천동',
#  '홍제동',
#  '충정로2가',
#  '홍제동',
#  '냉천동',
#  '연희동',
#  '북가좌동',
#  '홍제동',
#  '연희동',
#  '창천동',
#  '남가좌동',
#  '냉천동',
#  '연희동',
#  '남가좌동',
#  '남가좌동',
#  '옥천동',
#  '홍은동',
#  '북가좌동',
#  '창천동',
#  '창천동',
#  '북가좌동',
#  '홍은동',
#  '창천동',
#  '홍제동',
#  '홍제동',
#  '북가좌동',
#  '북아현동',
#  '창천동',
#  '창천동',
#  '남가좌동',
#  '홍제동',
#  '창천동',
#  '창천동',
#  '창천동',
#  '홍제동',
#  '창천동',
#  '충정로3가',
#  '북가좌동',
#  '홍제동',
#  '창천동',
#  '창천동',
#  '연희동',
#  '홍은동',
#  '창천동',
#  '냉천동',
#  '남가좌동',
#  '홍은동',
#  '창천동',
#  '연희동',
#  '창천동',
#  '연희동',
#  '남가좌동',
#  '창천동',
#  '홍은동',
#  '창천동',
#  '창천동',
#  '충정로3가',
#  '충정로2가',
#  '창천동',
#  '창천동',
#  '홍은동',
#  '연희동',
#  '창천동',
#  '미근동',
#  '북가좌동',
#  '북가좌동',
#  '북아현동',
#  '충정로2가',
#  '홍은동',
#  '북가좌동',
#  '창천동',
#  '창천동',
#  '홍은동',
#  '대현동',
#  '창천동',
#  '남가좌동',
#  '북가좌동',
#  '남가좌동',
#  '창천동',
#  '홍은동',
#  '연희동',
#  '창천동',
#  '창천동',
#  '창천동',
#  '창천동',
#  '홍제동',
#  '홍은동',
#  '연희동',
#  '남가좌동',
#  '충정로2가',
#  '홍은동',
#  '북아현동',
#  '창천동',
#  '홍제동',
#  '홍제동',
#  '대신동',
#  '북가좌동',
#  '북아현동',
#  '창천동',
#  '창천동',
#  '홍제동',
#  '북가좌동',
#  '창천동',
#  '창천동',
#  '창천동',
#  '북아현동',
#  '남가좌동',
#  '창천동',
#  '홍제동',
#  '홍제동',
#  '홍은동',
#  '홍은동',
#  '창천동',
#  '냉천동',
#  '홍제동',
#  '홍은동',
#  '홍제동',
#  '미근동',
#  '창천동',
#  '옥천동',
#  '미근동',
#  '창천동',
#  '창천동',
#  '홍은동',
#  '남가좌동',
#  '냉천동',
#  '홍제동',
#  '홍제동',
#  '북가좌동',
#  '창천동',
#  '창천동',
#  '창천동',
#  '창천동',
#  '홍은동',
#  '북가좌동',
#  '홍제동',
#  '남가좌동',
#  '연희동',
#  '창천동',
#  '창천동',
#  '홍제동',
#  '냉천동',
#  '홍제동',
#  '북가좌동',
#  '창천동',
#  '홍은동',
#  '북가좌동',
#  '연희동',
#  '연희동',
#  '연희동',
#  '연희동',
#  '홍제동',
#  '홍제동',
#  '연희동',
#  '창천동',
#  '창천동',
#  '홍은동',
#  '창천동',
#  '남가좌동',
#  '대현동',
#  '충정로2가',
#  '홍제동',
#  '북아현동',
#  '홍제동',
#  '홍제동',
#  '남가좌동',
#  '연희동',
#  '창천동',
#  '남가좌동',
#  '홍은동',
#  '창천동',
#  '홍은동',
#  '대현동',
#  '홍제동',
#  '홍제동',
#  '북아현동',
#  '북가좌동',
#  '창천동',
#  '대현동',
#  '연희동',
#  '남가좌동',
#  '영천동',
#  '대현동',
#  '북가좌동',
#  '홍제동',
#  '미근동',
#  '창천동',
#  '북가좌동',
#  '창천동',
#  '연희동',
#  '홍제동',
#  '북가좌동',
#  '홍은동',
#  '홍제동',
#  '남가좌동',
#  '홍은동',
#  '남가좌동',
#  '미근동',
#  '홍제동',
#  '연희동',
#  '창천동',
#  '창천동',
#  '북아현동',
#  '미근동',
#  '충정로2가',
#  '북가좌동',
#  '홍은동',
#  '홍제동',
#  '홍제동',
#  '홍은동',
#  '북가좌동',
#  '북가좌동',
#  '연희동',
#  '홍은동',
#  '북가좌동',
#  '남가좌동',
#  '북아현동',
#  '연희동',
#  '창천동',
#  '남가좌동',
#  '남가좌동',
#  '대현동',
#  '남가좌동',
#  '연희동',
#  '북가좌동',
#  '북가좌동',
#  '충정로3가',
#  '홍은동',
#  '연희동',
#  '충정로2가',
#  '창천동',
#  '합동',
#  '연희동',
#  '창천동',
#  '영천동',
#  '북가좌동',
#  '창천동',
#  '홍제동',
#  '창천동',
#  '충정로2가',
#  '창천동',
#  '남가좌동',
#  '연희동',
#  '북가좌동',
#  '홍은동',
#  '홍제동',
#  '홍은동',
#  '북가좌동',
#  '북가좌동',
#  '창천동',
#  '홍은동',
#  '홍제동',
#  '냉천동',
#  '북가좌동',
#  '남가좌동',
#  '충정로2가',
#  '북아현동',
#  '남가좌동',
#  '연희동',
#  '창천동',
#  '홍은동',
#  '북가좌동',
#  '남가좌동',
#  '창천동',
#  '창천동',
#  '남가좌동',
#  '북아현동',
#  '남가좌동',
#  '북가좌동',
#  '창천동',
#  '대현동',
#  '홍제동',
#  '남가좌동',
#  '창천동',
#  '북아현동',
#  '대현동',
#  '북가좌동',
#  '천연동',
#  '북가좌동',
#  '창천동',
#  '홍은동',
#  '창천동',
#  '북가좌동',
#  '홍제동',
#  '연희동',
#  '남가좌동',
#  '북아현동',
#  '창천동',
#  '연희동',
#  '북가좌동',
#  '합동',
#  '창천동',
#  '충정로2가',
#  '대현동',
#  '남가좌동',
#  '북가좌동',
#  '홍은동',
#  '홍은동',
#  '충정로3가',
#  '창천동',
#  '대현동',
#  '남가좌동',
#  '창천동',
#  '북가좌동',
#  '창천동',
#  '남가좌동',
#  '충정로2가',
#  '연희동',
#  '홍은동',
#  '창천동',
#  '냉천동',
#  '북가좌동',
#  '북가좌동',
#  '창천동',
#  '충정로3가',
#  '연희동',
#  '남가좌동',
#  '홍은동',
#  '북아현동',
#  '연희동',
#  '홍은동',
#  '북아현동',
#  '냉천동',
#  '연희동',
#  '홍은동',
#  '홍제동',
#  '남가좌동',
#  '연희동',
#  '홍제동',
#  '연희동',
#  '남가좌동',
#  '홍제동',
#  '북가좌동',
#  '창천동',
#  '북아현동',
#  '창천동',
#  '냉천동',
#  '남가좌동',
#  '북가좌동',
#  '북아현동',
#  '홍제동',
#  '남가좌동',
#  '충정로3가',
#  '연희동',
#  '홍은동',
#  '대현동',
#  '대현동',
#  '대현동',
#  '홍은동',
#  '연희동',
#  '남가좌동',
#  '홍은동',
#  '연희동',
#  '북가좌동',
#  '홍은동',
#  '옥천동',
#  '홍제동',
#  '남가좌동',
#  '대현동',
#  '홍은동',
#  '충정로3가',
#  '북가좌동',
#  '남가좌동',
#  '충정로3가',
#  '충정로2가',
#  '대현동',
#  '창천동',
#  '연희동',
#  '홍은동',
#  '충정로3가',
#  '홍제동',
#  '북가좌동',
#  '연희동',
#  '천연동',
#  '창천동',
#  '북가좌동',
#  '북가좌동',
#  '창천동',
#  '남가좌동',
#  '남가좌동',
#  '창천동',
#  '창천동',
#  '북아현동',
#  '남가좌동',
#  '홍제동',
#  '홍제동',
#  '북아현동',
#  '남가좌동']

# %%
chicken_w = chicken_w[chicken_w['지역구']=='서대문구']

# %%
chicken_w
# Out:
#             번호 개방서비스명    개방서비스아이디  개방자치단체코드                    관리번호     인허가일자  \
# 178        179  일반음식점  07_24_04_P   3120000  3120000-101-1997-05915  19970217
# 698        699  일반음식점  07_24_04_P   3120000  3120000-101-2019-00009  20190111
# 724        725  일반음식점  07_24_04_P   3120000  3120000-101-2019-00020  20190123
# 1200      1201  일반음식점  07_24_04_P   3120000  3120000-101-2019-00061  20190314
# 1405      1406  일반음식점  07_24_04_P   3120000  3120000-101-2019-00014  20190116
# ...        ...    ...         ...       ...                     ...       ...
# 122500  122501  일반음식점  07_24_04_P   3120000  3120000-101-2020-00340  20201207
# 123490  123491  일반음식점  07_24_04_P   3120000  3120000-101-2021-00042  20210203
# 123548  123549  일반음식점  07_24_04_P   3120000  3120000-101-2021-00015  20210114
# 123724  123725  일반음식점  07_24_04_P   3120000  3120000-101-2021-00022  20210118
# 124130  124131  일반음식점  07_24_04_P   3120000  3120000-101-2021-00031  20210122
#
#         인허가취소일자  영업상태구분코드  영업상태명  상세영업상태코드  ... 보증액  월세액  다중이용업소여부   시설총규모  \
# 178         NaN         1  영업/정상         1  ... NaN  NaN         N  147.90
# 698         NaN         1  영업/정상         1  ... NaN  NaN         N   20.80
# 724         NaN         1  영업/정상         1  ... NaN  NaN         N   43.00
# 1200        NaN         1  영업/정상         1  ... NaN  NaN         N   33.05
# 1405        NaN         1  영업/정상         1  ... NaN  NaN         N   64.00
# ...         ...       ...    ...       ...  ...  ..  ...       ...     ...
# 122500      NaN         1  영업/정상         1  ... NaN  NaN         N   65.92
# 123490      NaN         1  영업/정상         1  ... NaN  NaN         N   62.40
# 123548      NaN         1  영업/정상         1  ... NaN  NaN         N   20.62
# 123724      NaN         1  영업/정상         1  ... NaN  NaN         N   34.32
# 124130      NaN         1  영업/정상         1  ... NaN  NaN         N   49.34
#
#         전통업소지정번호 전통업소주된음식 홈페이지  Unnamed: 47   지역구   동이름
# 178          NaN      NaN  NaN          NaN  서대문구   창천동
# 698          NaN      NaN  NaN          NaN  서대문구   홍제동
# 724          NaN      NaN  NaN          NaN  서대문구  남가좌동
# 1200         NaN      NaN  NaN          NaN  서대문구   연희동
# 1405         NaN      NaN  NaN          NaN  서대문구   창천동
# ...          ...      ...  ...          ...   ...   ...
# 122500       NaN      NaN  NaN          NaN  서대문구  남가좌동
# 123490       NaN      NaN  NaN          NaN  서대문구   홍제동
# 123548       NaN      NaN  NaN          NaN  서대문구   홍제동
# 123724       NaN      NaN  NaN          NaN  서대문구  북아현동
# 124130       NaN      NaN  NaN          NaN  서대문구  남가좌동
#
# [400 rows x 50 columns]

# %%
chicken_w = chicken_w[chicken_w['지역구']=='서대문구']

# %%
#동별 치킨집 개수

chicken_count = chicken_w['동이름'].value_counts()
chicken_count = chicken_count.to_dict()

label = list(chicken_count.keys())
size = list(chicken_count.values())

# %%
plt.figure(figsize=(8,6))
squarify.plot(sizes=size, label=label)
plt.title('서대문구 동별 치킨집 트리맵')
plt.show()
# Out:
# <Axes: >
# Text(0.5, 1.0, '서대문구 동별 치킨집 트리맵')
