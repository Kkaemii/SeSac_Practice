# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
#주피터에서 실행결과 여러줄 보여주고싶을때
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"
import squarify

# %%
#폰트 확인

import matplotlib.font_manager as fm
fontlist = fm.findSystemFonts(fontpaths=None, fontext='ttf')

f = [f.name for f in fm.fontManager.ttflist]
print(f'{f} \n')

# 한글 폰트 경로 설정 (예: 맑은 고딕)
font_path = r'C:\Windows\Fonts\malgun.ttf'  # Windows 기준
font_prop = fm.FontProperties(fname=font_path)

# 폰트 설정 적용
plt.rcParams['font.family'] = font_prop.get_name()
# Out:
# ['STIXGeneral', 'DejaVu Sans', 'DejaVu Sans Mono', 'DejaVu Sans', 'DejaVu Serif Display', 'STIXSizeTwoSym', 'DejaVu Sans Mono', 'STIXSizeThreeSym', 'STIXNonUnicode', 'DejaVu Sans Mono', 'DejaVu Serif', 'cmss10', 'cmex10', 'DejaVu Serif', 'STIXSizeTwoSym', 'STIXSizeFiveSym', 'STIXSizeFourSym', 'STIXSizeOneSym', 'STIXNonUnicode', 'DejaVu Sans', 'STIXGeneral', 'DejaVu Serif', 'STIXSizeOneSym', 'STIXSizeThreeSym', 'STIXNonUnicode', 'DejaVu Serif', 'cmr10', 'DejaVu Sans', 'DejaVu Sans Mono', 'cmmi10', 'cmb10', 'STIXGeneral', 'cmtt10', 'DejaVu Sans Display', 'STIXSizeFourSym', 'STIXGeneral', 'cmsy10', 'STIXNonUnicode', 'Tw Cen MT', 'Haan Cooljazz M', 'Modern No. 20', 'Informal Roman', 'Bell MT', 'Arial', 'HYgsrB', 'Yj BONMOKGAK Medium ', 'Georgia', 'HCR Dotum', 'Pyunji R', 'Franklin Gothic Book', 'NanumSquare', 'HYkanB', 'HYwulB', 'Bodoni MT', 'Californian FB', 'Verdana', 'Segoe MDL2 Assets', 'ahn2006-M', 'GoudyOlSt BT', '??????', 'GoudyOlSt BT', 'Eras Medium ITC', 'MJemokGothic', 'HyhwpEQ', 'Yet R', 'MGungHeulim', 'DomCasual BT', 'Gill Sans MT Ext Condensed Bold', 'Lucida Bright', 'Colonna MT', 'Times New Roman', 'Arial Rounded MT Bold', 'Microsoft JhengHei', 'NanumSquareOTF', 'Calibri', 'MBatang', 'Lucida Sans Unicode', 'HYPost-Light', 'MS Gothic', 'MT Extra', 'Constantia', 'Blackadder ITC', 'Candara', 'Yu Gothic', 'Hobo BT', 'Haansoft Batang', 'Magic R', 'Microsoft Himalaya', 'Book Antiqua', 'Engravers MT', 'Bradley Hand ITC', 'Bodoni MT', 'Brush Script MT', 'Century Schoolbook', 'Haan YGodic 230', 'Segoe Print', 'HYsnrL', 'Sitka Small', 'Elephant', 'Microsoft YaHei', 'Microsoft Tai Le', 'Bookman Old Style', 'Bodoni MT', 'Bookman Old Style', 'MJemokBatang', 'Yj SHANALL Medium ', 'Tahoma', 'Kunstler Script', 'Yj BLOCK Medium', 'Chiller', 'Script MT Bold', 'Segoe UI', 'NanumSquareOTF', 'Lucida Bright', 'Microsoft Uighur', 'Calibri', 'YJ BELLA Medium', 'Bodoni MT', 'Magneto', 'Algerian', 'Garamond', 'HYSinMyeongJo-Medium', 'Lucida Sans', 'NanumSquareOTF_ac', 'Wide Latin', 'MurrayHill Bd BT', 'MingLiU-ExtB', 'Yj SOSEL SemiBold', 'Perpetua', 'Lucida Sans', 'Bookman Old Style', 'Bodoni Bk BT', 'HCR Batang', 'Lucida Calligraphy', 'Lucida Sans Typewriter', 'NanumSquare', 'Gulim', 'AmeriGarmnd BT', 'Leelawadee', 'Cambria', 'Calisto MT', '??????', 'NanumGothic', 'Wingdings 2', 'Sitka Small', 'Mongolian Baiti', 'Arial', 'Goudy Old Style', 'YJ INJANG Medium', 'Franklin Gothic Heavy', 'Lucida Fax', 'Myanmar Text', 'Yu Gothic', 'HYtbrB', 'Playbill', 'Matura MT Script Capitals', 'Snap ITC', 'NanumSquareOTF_ac', '????', 'Rockwell', 'Gadugi', 'HCR Dotum Ext', 'Arial Unicode MS', 'Courier New', 'Microsoft YaHei', 'Meiryo', 'Bernard MT Condensed', 'Yj DOOLGI Medium', 'Microsoft New Tai Lue', 'Mistral', 'Baskerville Old Face', 'Consolas', '????', 'HYMyeongJo-Extra', 'Ami R', 'Stencil', 'Segoe Script', 'NanumSquare_ac', 'Palatino Linotype', 'MGungJeong', 'Impact', 'OCR-A BT', 'Perpetua Titling MT', 'Forte', 'Segoe UI', 'HYPost-Medium', 'Comic Sans MS', 'Symbol', 'Centaur', 'Lucida Fax', 'Courier10 BT', 'Bookman Old Style', 'Perpetua Titling MT', 'Nirmala UI', 'Arial', 'Gill Sans Ultra Bold Condensed', 'Microsoft JhengHei', 'HYgtrE', 'Bell MT', 'ParkAvenue BT', 'Nirmala UI', 'Swis721 BT', 'Book Antiqua', 'Candara', 'Vivaldi', 'Dubai', 'Poor Richard', 'Courier New', 'MSugiHeulim', 'MSugiJeong', 'Rage Italic', 'Bodoni MT', 'Malgun Gothic', 'Perpetua', 'SimSun-ExtB', 'MDEasop', 'HYnamM', 'Segoe UI', 'HYmprL', 'Stencil BT', 'HoloLens MDL2 Assets', 'Segoe UI Symbol', 'Constantia', 'Arial', 'Segoe UI', 'Consolas', 'CentSchbook BT', 'NanumSquare_ac', 'Copperplate Gothic Bold', 'Bodoni MT', 'Yj GOTGAE Medium', 'Gill Sans MT Condensed', 'Californian FB', 'NanumSquareOTF_ac', 'Javanese Text', 'Lucida Console', 'Orbit-B BT', 'NanumSquare', 'HYbdaM', 'Californian FB', 'Papyrus', 'Monotype Corsiva', 'Webdings', 'Segoe UI Emoji', 'Segoe Script', 'HYsupM', 'Microsoft New Tai Lue', 'Old English Text MT', 'Consolas', 'Agency FB', 'Britannic Bold', 'Tw Cen MT', 'Segoe  ...

# %%
df =pd.read_csv('./서울특별시_일반음식점.csv', sep=',', encoding='cp949')
df.head(10)
# Out:
# C:\Users\hhhmh\AppData\Local\Temp\ipykernel_25492\3397017031.py:1: DtypeWarning: Columns (22,27,39,41,44,45) have mixed types. Specify dtype option on import or set low_memory=False.
#   df =pd.read_csv('./서울특별시_일반음식점.csv', sep=',', encoding='cp949')
#    번호 개방서비스명    개방서비스아이디  개방자치단체코드                    관리번호     인허가일자  인허가취소일자  \
# 0   1  일반음식점  07_24_04_P   3150000  3150000-101-2020-00448  20200803      NaN
# 1   2  일반음식점  07_24_04_P   3150000  3150000-101-2020-00449  20200803      NaN
# 2   3  일반음식점  07_24_04_P   3220000  3220000-101-2020-00851  20200803      NaN
# 3   4  일반음식점  07_24_04_P   3220000  3220000-101-2020-00853  20200803      NaN
# 4   5  일반음식점  07_24_04_P   3220000  3220000-101-2020-00855  20200803      NaN
# 5   6  일반음식점  07_24_04_P   3220000  3220000-101-2020-00856  20200803      NaN
# 6   7  일반음식점  07_24_04_P   3040000  3040000-101-2020-00273  20200803      NaN
# 7   8  일반음식점  07_24_04_P   3040000  3040000-101-2020-00276  20200803      NaN
# 8   9  일반음식점  07_24_04_P   3110000  3110000-101-2020-00280  20200803      NaN
# 9  10  일반음식점  07_24_04_P   3110000  3110000-101-2020-00281  20200803      NaN
#
#    영업상태구분코드  영업상태명  상세영업상태코드  ... 공장생산직종업원수  건물소유구분명  보증액  월세액  다중이용업소여부  \
# 0         1  영업/정상         1  ...       NaN      NaN  NaN  NaN         N
# 1         1  영업/정상         1  ...       NaN      NaN  NaN  NaN         N
# 2         1  영업/정상         1  ...       0.0      NaN  0.0  0.0         N
# 3         1  영업/정상         1  ...       NaN      NaN  NaN  NaN         Y
# 4         1  영업/정상         1  ...       NaN      NaN  NaN  NaN         N
# 5         1  영업/정상         1  ...       NaN      NaN  NaN  NaN         Y
# 6         1  영업/정상         1  ...       NaN      NaN  NaN  NaN         N
# 7         1  영업/정상         1  ...       NaN      NaN  NaN  NaN         N
# 8         1  영업/정상         1  ...       NaN      NaN  NaN  NaN         N
# 9         1  영업/정상         1  ...       NaN      NaN  NaN  NaN         N
#
#     시설총규모 전통업소지정번호  전통업소주된음식 홈페이지 Unnamed: 47
# 0   35.19      NaN       NaN  NaN         NaN
# 1   50.37      NaN       NaN  NaN         NaN
# 2   13.65      NaN       NaN  NaN         NaN
# 3  123.30      NaN       NaN  NaN         NaN
# 4    8.26      NaN       NaN  NaN         NaN
# 5  115.00      NaN       NaN  NaN         NaN
# 6   15.39      NaN       NaN  NaN         NaN
# 7  112.91      NaN       NaN  NaN         NaN
# 8   40.00      NaN       NaN  NaN         NaN
# 9   63.44      NaN       NaN  NaN         NaN
#
# [10 rows x 48 columns]

# %%
#서대문구 치킨집 개수 트리맵으로
#파이그래프,히트맵,막대그래프, 히트맵 등 다양하게
#치킨집 분포 확인하는게 목표

# %%
df['사업장명'],
df[df['업태구분명']=='호프/통닭'].head()
df[df['업태구분명']=='통닭(치킨)'].head()
# Out:
# (0                   혼밥대왕 마곡점
#  1                꾸어가게생선구이화곡점
#  2                      인생갈비탕
#  3                놀부 공유주방 선릉역
#  4                        온기정
#                   ...
#  472910      샐러드랩 샐랩 춘하추동프로젝트
#  472911                  노지푸드
#  472912    포베이키친밸리논현2호점 주방22호
#  472913                개성진 만두
#  472914                  동행포차
#  Name: 사업장명, Length: 472915, dtype: object,)
#     번호 개방서비스명    개방서비스아이디  개방자치단체코드                    관리번호     인허가일자  \
# 30  31  일반음식점  07_24_04_P   3110000  3110000-101-1999-06737  19991113
# 43  44  일반음식점  07_24_04_P   3180000  3180000-101-2001-14282  20010818
# 44  45  일반음식점  07_24_04_P   3010000  3010000-101-2001-13779  20010521
# 66  67  일반음식점  07_24_04_P   3000000  3000000-101-2002-11870  20020205
# 67  68  일반음식점  07_24_04_P   3210000  3210000-101-2000-15274  20001201
#
#     인허가취소일자  영업상태구분코드  영업상태명  상세영업상태코드  ... 공장생산직종업원수  건물소유구분명  보증액  월세액  \
# 30      NaN         1  영업/정상         1  ...       NaN      NaN  NaN  NaN
# 43      NaN         1  영업/정상         1  ...       0.0      NaN  0.0  0.0
# 44      NaN         1  영업/정상         1  ...       NaN      NaN  NaN  NaN
# 66      NaN         1  영업/정상         1  ...       NaN      NaN  NaN  NaN
# 67      NaN         1  영업/정상         1  ...       NaN      NaN  NaN  NaN
#
#     다중이용업소여부  시설총규모 전통업소지정번호  전통업소주된음식 홈페이지 Unnamed: 47
# 30         N  60.28      NaN       NaN  NaN         NaN
# 43         N  12.00      NaN       NaN  NaN         NaN
# 44         N  28.60      NaN       NaN  NaN         NaN
# 66         N  41.87      NaN       NaN  NaN         NaN
# 67         N  19.80      NaN       NaN  NaN         NaN
#
# [5 rows x 48 columns]
#       번호 개방서비스명    개방서비스아이디  개방자치단체코드                    관리번호     인허가일자  \
# 178  179  일반음식점  07_24_04_P   3120000  3120000-101-1997-05915  19970217
# 241  242  일반음식점  07_24_04_P   3110000  3110000-101-2014-00038  20140224
# 270  271  일반음식점  07_24_04_P   3110000  3110000-101-2014-00321  20141021
# 302  303  일반음식점  07_24_04_P   3110000  3110000-101-1999-06735  19991113
# 384  385  일반음식점  07_24_04_P   3110000  3110000-101-2001-07849  20010409
#
#      인허가취소일자  영업상태구분코드  영업상태명  상세영업상태코드  ... 공장생산직종업원수  건물소유구분명  보증액  월세액  \
# 178      NaN         1  영업/정상         1  ...       NaN      NaN  NaN  NaN
# 241      NaN         1  영업/정상         1  ...       NaN      NaN  NaN  NaN
# 270      NaN         1  영업/정상         1  ...       NaN      NaN  NaN  NaN
# 302      NaN         1  영업/정상         1  ...       NaN      NaN  NaN  NaN
# 384      NaN         1  영업/정상         1  ...       NaN      NaN  NaN  NaN
#
#      다중이용업소여부   시설총규모 전통업소지정번호  전통업소주된음식 홈페이지 Unnamed: 47
# 178         N  147.90      NaN       NaN  NaN         NaN
# 241         N   58.55      NaN       NaN  NaN         NaN
# 270         N   85.80      NaN       NaN  NaN         NaN
# 302         N   23.95      NaN       NaN  NaN         NaN
# 384         N   39.60      NaN       NaN  NaN         NaN
#
# [5 rows x 48 columns]

# %%
chicken_w = df.loc[df['영업상태구분코드']==1 & df['업태구분명'].str.contains('호프|통닭|치킨')]
chicken_w= chicken_w.reset_index(drop=True, names='index')
chicken_w.drop('번호', axis=1,inplace=True)

# %%
#업태구분명이 호프/통닭 이거나 통닭(치킨)이고 현재 영업중인 영업상태 1인 가게들
chicken_w.head()
# Out:
#   개방서비스명    개방서비스아이디  개방자치단체코드                    관리번호     인허가일자  인허가취소일자  \
# 0  일반음식점  07_24_04_P   3110000  3110000-101-1999-06737  19991113      NaN
# 1  일반음식점  07_24_04_P   3180000  3180000-101-2001-14282  20010818      NaN
# 2  일반음식점  07_24_04_P   3010000  3010000-101-2001-13779  20010521      NaN
# 3  일반음식점  07_24_04_P   3000000  3000000-101-2002-11870  20020205      NaN
# 4  일반음식점  07_24_04_P   3210000  3210000-101-2000-15274  20001201      NaN
#
#    영업상태구분코드  영업상태명  상세영업상태코드 상세영업상태명  ...  공장생산직종업원수  건물소유구분명  보증액  월세액  \
# 0         1  영업/정상         1      영업  ...        NaN      NaN  NaN  NaN
# 1         1  영업/정상         1      영업  ...        0.0      NaN  0.0  0.0
# 2         1  영업/정상         1      영업  ...        NaN      NaN  NaN  NaN
# 3         1  영업/정상         1      영업  ...        NaN      NaN  NaN  NaN
# 4         1  영업/정상         1      영업  ...        NaN      NaN  NaN  NaN
#
#   다중이용업소여부  시설총규모  전통업소지정번호 전통업소주된음식 홈페이지  Unnamed: 47
# 0        N  60.28       NaN      NaN  NaN          NaN
# 1        N  12.00       NaN      NaN  NaN          NaN
# 2        N  28.60       NaN      NaN  NaN          NaN
# 3        N  41.87       NaN      NaN  NaN          NaN
# 4        N  19.80       NaN      NaN  NaN          NaN
#
# [5 rows x 47 columns]

# %%
chicken_w['소재지전체주소']  = chicken_w['소재지전체주소'].fillna(chicken_w['도로명전체주소'])
chicken_w['소재지전체주소'].isnull().sum()
# Out:
# 0

# %%
chicken_w
# Out:
#       개방서비스명    개방서비스아이디  개방자치단체코드                    관리번호     인허가일자  인허가취소일자  \
# 0      일반음식점  07_24_04_P   3110000  3110000-101-1999-06737  19991113      NaN
# 1      일반음식점  07_24_04_P   3180000  3180000-101-2001-14282  20010818      NaN
# 2      일반음식점  07_24_04_P   3010000  3010000-101-2001-13779  20010521      NaN
# 3      일반음식점  07_24_04_P   3000000  3000000-101-2002-11870  20020205      NaN
# 4      일반음식점  07_24_04_P   3210000  3210000-101-2000-15274  20001201      NaN
# ...      ...         ...       ...                     ...       ...      ...
# 13105  일반음식점  07_24_04_P   3120000  3120000-101-2021-00031  20210122      NaN
# 13106  일반음식점  07_24_04_P   3160000  3160000-101-2020-00384  20201208      NaN
# 13107  일반음식점  07_24_04_P   3200000  3200000-101-2020-00626  20201209      NaN
# 13108  일반음식점  07_24_04_P   3060000  3060000-101-2021-00028  20210203      NaN
# 13109  일반음식점  07_24_04_P   3080000  3080000-101-2021-00015  20210122      NaN
#
#        영업상태구분코드  영업상태명  상세영업상태코드 상세영업상태명  ...  공장생산직종업원수  건물소유구분명  보증액  월세액  \
# 0             1  영업/정상         1      영업  ...        NaN      NaN  NaN  NaN
# 1             1  영업/정상         1      영업  ...        0.0      NaN  0.0  0.0
# 2             1  영업/정상         1      영업  ...        NaN      NaN  NaN  NaN
# 3             1  영업/정상         1      영업  ...        NaN      NaN  NaN  NaN
# 4             1  영업/정상         1      영업  ...        NaN      NaN  NaN  NaN
# ...         ...    ...       ...     ...  ...        ...      ...  ...  ...
# 13105         1  영업/정상         1      영업  ...        NaN      NaN  NaN  NaN
# 13106         1  영업/정상         1      영업  ...        NaN      NaN  NaN  NaN
# 13107         1  영업/정상         1      영업  ...        NaN      NaN  NaN  NaN
# 13108         1  영업/정상         1      영업  ...        NaN      NaN  NaN  NaN
# 13109         1  영업/정상         1      영업  ...        NaN      NaN  NaN  NaN
#
#       다중이용업소여부  시설총규모  전통업소지정번호 전통업소주된음식 홈페이지  Unnamed: 47
# 0            N  60.28       NaN      NaN  NaN          NaN
# 1            N  12.00       NaN      NaN  NaN          NaN
# 2            N  28.60       NaN      NaN  NaN          NaN
# 3            N  41.87       NaN      NaN  NaN          NaN
# 4            N  19.80       NaN      NaN  NaN          NaN
# ...        ...    ...       ...      ...  ...          ...
# 13105        N  49.34       NaN      NaN  NaN          NaN
# 13106        N  33.00       NaN      NaN  NaN          NaN
# 13107        N  62.80       NaN      NaN  NaN          NaN
# 13108        N  53.84       NaN      NaN  NaN          NaN
# 13109        N  40.00       NaN      NaN  NaN          NaN
#
# [13110 rows x 47 columns]

# %%
f_add =chicken_w['소재지전체주소'].values.tolist()

gu=[]
dong=[]
for i in f_add:
  gu.append(i.split(sep=' ')[1])
  
for i in f_add:
  dong.append(i.split(sep=' ')[2])

# %%
chicken_w['지역구'] = gu
chicken_w['동이름'] = dong

# %%
gu
# Out:
# ['은평구',
#  '영등포구',
#  '중구',
#  '종로구',
#  '서초구',
#  '성북구',
#  '은평구',
#  '은평구',
#  '영등포구',
#  '서대문구',
#  '서초구',
#  '서초구',
#  '은평구',
#  '종로구',
#  '은평구',
#  '양천구',
#  '은평구',
#  '종로구',
#  '은평구',
#  '은평구',
#  '은평구',
#  '은평구',
#  '은평구',
#  '은평구',
#  '은평구',
#  '은평구',
#  '은평구',
#  '관악구',
#  '송파구',
#  '관악구',
#  '광진구',
#  '영등포구',
#  '강서구',
#  '구로구',
#  '은평구',
#  '금천구',
#  '영등포구',
#  '강서구',
#  '서초구',
#  '양천구',
#  '강북구',
#  '노원구',
#  '성동구',
#  '노원구',
#  '영등포구',
#  '동작구',
#  '양천구',
#  '서대문구',
#  '중구',
#  '서대문구',
#  '구로구',
#  '중랑구',
#  '서초구',
#  '구로구',
#  '광진구',
#  '중구',
#  '노원구',
#  '노원구',
#  '은평구',
#  '송파구',
#  '강남구',
#  '서초구',
#  '강북구',
#  '강서구',
#  '금천구',
#  '동작구',
#  '금천구',
#  '용산구',
#  '중구',
#  '동작구',
#  '서초구',
#  '강북구',
#  '은평구',
#  '은평구',
#  '성북구',
#  '송파구',
#  '송파구',
#  '서대문구',
#  '동작구',
#  '노원구',
#  '금천구',
#  '영등포구',
#  '관악구',
#  '성북구',
#  '강남구',
#  '종로구',
#  '종로구',
#  '은평구',
#  '강남구',
#  '광진구',
#  '금천구',
#  '성동구',
#  '금천구',
#  '양천구',
#  '동작구',
#  '도봉구',
#  '영등포구',
#  '서대문구',
#  '구로구',
#  '중구',
#  '영등포구',
#  '구로구',
#  '성동구',
#  '강남구',
#  '동대문구',
#  '노원구',
#  '관악구',
#  '도봉구',
#  '용산구',
#  '광진구',
#  '영등포구',
#  '서초구',
#  '종로구',
#  '은평구',
#  '양천구',
#  '양천구',
#  '양천구',
#  '강동구',
#  '도봉구',
#  '성북구',
#  '동대문구',
#  '은평구',
#  '강동구',
#  '강동구',
#  '동대문구',
#  '양천구',
#  '동작구',
#  '동작구',
#  '강북구',
#  '강북구',
#  '노원구',
#  '서대문구',
#  '도봉구',
#  '동대문구',
#  '강남구',
#  '송파구',
#  '노원구',
#  '구로구',
#  '은평구',
#  '노원구',
#  '도봉구',
#  '광진구',
#  '서초구',
#  '도봉구',
#  '도봉구',
#  '용산구',
#  '서초구',
#  '서초구',
#  '성동구',
#  '은평구',
#  '용산구',
#  '중구',
#  '용산구',
#  '양천구',
#  '중구',
#  '중구',
#  '양천구',
#  '성동구',
#  '은평구',
#  '은평구',
#  '성동구',
#  '성동구',
#  '종로구',
#  '은평구',
#  '용산구',
#  '양천구',
#  '종로구',
#  '은평구',
#  '용산구',
#  '성북구',
#  '성동구',
#  '성동구',
#  '영등포구',
#  '양천구',
#  '종로구',
#  '종로구',
#  '은평구',
#  '송파구',
#  '은평구',
#  '영등포구',
#  '영등포구',
#  '종로구',
#  '종로구',
#  '용산구',
#  '성동구',
#  '성동구',
#  '은평구',
#  '중구',
#  '은평구',
#  '중구',
#  '은평구',
#  '은평구',
#  '종로구',
#  '중구',
#  '은평구',
#  '성동구',
#  '성동구',
#  '은평구',
#  '성동구',
#  '서대문구',
#  '은평구',
#  '은평구',
#  '종로구',
#  '은평구',
#  '서초구',
#  '은평구',
#  '성동구',
#  '서대문구',
#  '성동구',
#  '성동구',
#  '서대문구',
#  '은평구',
#  '성동구',
#  '서대문구',
#  '은평구',
#  '은평구',
#  '성동구',
#  '은평구',
#  '성동구',
#  '양천구',
#  '양천구',
#  '은평구',
#  '서초구',
#  '양천구',
#  '양천구',
#  '성동구',
#  '서대문구',
#  '양천구',
#  '양천구',
#  '서대문구',
#  '서초구',
#  '중구',
#  '은평구',
#  '종로구',
#  '영등포구',
#  '종로구',
#  '성동구',
#  '양천구',
#  '영등포구',
#  '양천구',
#  '은평구',
#  '종로구',
#  '양천구',
#  '서초구',
#  '서초구',
#  '서초구',
#  '영등포구',
#  '은평구',
#  '은평구',
#  '은평구',
#  '양천구',
#  '은평구',
#  '은평구',
#  '양천구',
#  '양천구',
#  '은평구',
#  '영등포구',
#  '은평구',
#  '종로구',
#  '양천구',
#  '영등포구',
#  '은평구',
#  '양천구',
#  '송파구',
#  '은평구',
#  '중구',
#  '서대문구',
#  '은평구',
#  '중구',
#  '종로구',
#  '은평구',
#  '중구',
#  '성동구',
#  '양천구',
#  '양천구',
#  '양천구',
#  '양천구',
#  '은평구',
#  '양천구',
#  '양천구',
#  '은평구',
#  '은평구',
#  '서대문구',
#  '성동구',
#  '성동구',
#  '은평구',
#  '성동구',
#  '은평구',
#  '은평구',
#  '성동구',
#  '양천구',
#  '은평구',
#  '양천구',
#  '은평구',
#  '은평구',
#  '은평구',
#  '양천구',
#  '용산구',
#  '서대문구',
#  '은평구',
#  '은평구',
#  '은평구',
#  '중구',
#  '양천구',
#  '양천구',
#  '서초구',
#  '양천구',
#  '양천구',
#  '서대문구',
#  '양천구',
#  '은평구',
#  '성북구',
#  '양천구',
#  '용산구',
#  '은평구',
#  '양천구',
#  '영등포구',
#  '은평구',
#  '종로구',
#  '은평구',
#  '양천구',
#  '용산구',
#  '성동구',
#  '양천구',
#  '서초구',
#  '성동구',
#  '영등포구',
#  '은평구',
#  '용산구',
#  '서초구',
#  '서대문구',
#  '은평구',
#  '중구',
#  '은평구',
#  '용산구',
#  '성북구',
#  '양천구',
#  '은평구',
#  '은평구',
#  '서대문구',
#  '서대문구',
#  '성동구',
#  '성동구',
#  '중구',
#  '양천구',
#  '성동구',
#  '중구',
#  '양천구',
#  '영등포구',
#  '양천구',
#  '서대문구',
#  '양천구',
#  '서대문구',
#  '용산구',
#  '중구',
#  '은평구',
#  '송파구',
#  '서대문구',
#  '양천구',
#  '성북구',
#  '영등포구',
#  '영등포구',
#  '은평구',
#  '성동구',
#  '성동구',
#  '성동구',
#  '중구',
#  '서대문구',
#  '성북구',
#  '은평구',
#  '은평구',
#  '은평구',
#  '성동구',
#  '양천구',
#  '은평구',
#  '성동구',
#  '서초구',
#  '은평구',
#  '양천구',
#  '양천구',
#  '양천구',
#  '서초구',
#  '은평구',
#  '양천구',
#  '성동구',
#  '은평구',
#  '은평구',
#  '영등포구',
#  '서초구',
#  '은평구',
#  '은평구',
#  '은평구',
#  '은평구',
#  '양천구',
#  '은평구',
#  '성동구',
#  '은평구',
#  '은평구',
#  '양천구',
#  '은평구',
#  '영등포구',
#  '성동구',
#  '은평구',
#  '은평구',
#  '양천구',
#  '영등포구',
#  '은평구',
#  '은평구',
#  '은평구',
#  '서대문구',
#  '양천구',
#  '종로구',
#  '은평구',
#  '서초구',
#  '영등포구',
#  '양천구',
#  '성북구',
#  '양천구',
#  '양천구',
#  '영등포구',
#  '양천구',
#  '성북구',
#  '서초구',
#  '용산구',
#  '은평구',
#  '양천구',
#  '서대문구',
#  '영등포구',
#  '양천구',
#  '용산구',
#  '은평구',
#  '용산구',
#  '서초구',
#  '은평구',
#  '양천구',
#  '성동구',
#  '종로구',
#  '용산구',
#  '중구',
#  '성북구',
#  '서초구',
#  '서대문구',
#  '양천구',
#  '은평구',
#  '서대문구',
#  '은평구',
#  '은평구',
#  '은평구',
#  '종로구',
#  '중구',
#  '종로구',
#  '용산구',
#  '은평구',
#  '영등포구',
#  '서초구',
#  '종로구',
#  '종로구',
#  '서초구',
#  '종로구',
#  '양천구',
#  '종로구',
#  '은평구',
#  '은평구',
#  '은평구',
#  '서초구',
#  '서대문구',
#  '은평구',
#  '성북구',
#  '성북구',
#  '영등포구',
#  '영등포구',
#  '양천구',
#  '종로구',
#  '은평구',
#  '은평구',
#  '성북구',
#  '영등포구',
#  '은평구',
#  '종로구',
#  '양천구',
#  '양천구',
#  '은평구',
#  '중구',
#  '은평구',
#  '은평구',
#  '성북구',
#  '용산구',
#  '종로구',
#  '서대문구',
#  '양천구',
#  '성동구',
#  '영등포구',
#  '은평구',
#  '종로구',
#  '성북구',
#  '은평구',
#  '종로구',
#  '양천구',
#  '양천구',
#  '성동구',
#  '서초구',
#  '성동구',
#  '용산구',
#  '은평구',
#  '영등포구',
#  '은평구',
#  '서대문구',
#  '용산구',
#  '은평구',
#  '용산구',
#  '은평구',
#  '종로구',
#  '양천구',
#  '은평구',
#  '용산구',
#  '은평구',
#  '은평구',
#  '은평구',
#  '은평구',
#  '은평구',
#  '송파구',
#  '종로구',
#  '은평구',
#  '은평구',
#  '은평구',
#  '용산구',
#  '용산구',
#  '은평구',
#  '은평구',
#  '은평구',
#  '은평구',
#  '용산구',
#  '성북구',
#  '은평구',
#  '중구',
#  '은평구',
#  '용산구',
#  '은평구',
#  '양천구',
#  '은평구',
#  '중구',
#  '종로구',
#  '은평구',
#  '은평구',
#  '은평구',
#  '은평구',
#  '용산구',
#  '종로구',
#  '중구',
#  '영등포구',
#  '양천구',
#  '송파구',
#  '중구',
#  '종로구',
#  '성동구',
#  '서초구',
#  '종로구',
#  '서초구',
#  '서대문구',
#  '양천구',
#  '송파구',
#  '성동구',
#  '서초구',
#  '서대문구',
#  '중구',
#  '은평구',
#  '서대문구',
#  '성북구',
#  '영등포구',
#  '종로구',
#  '성동구',
#  '서대문구',
#  '성북구',
#  '중구',
#  '성동구',
#  '성동구',
#  '서대문구',
#  '중구',
#  '은평구',
#  '영등포구',
#  '용산구',
#  '서초구',
#  '서대문구',
#  '은평구',
#  '서초구',
#  '양천구',
#  '은평구',
#  '성동구',
#  '성동구',
#  '중구',
#  '중구',
#  '용산구',
#  '중구',
#  '성동구',
#  '용산구',
#  '서대문구',
#  '은평구',
#  '은평구',
#  '성동구',
#  '은평구',
#  '은평구',
#  '송파구',
#  '은평구',
#  '중구',
#  '양천구',
#  '양천구',
#  '성동구',
#  '서초구',
#  '용산구',
#  '중구',
#  '서대문구',
#  '서대문구',
#  '중구',
#  '은평구',
#  '서초구',
#  '송파구',
#  '송파구',
#  '은평구',
#  '성동구',
#  '성동구',
#  '용산구',
#  '성동구',
#  '은평구',
#  '서초구',
#  '성북구',
#  '서초구',
#  '은평구',
#  '서초구',
#  '중구',
#  '용산구',
#  '중구',
#  '양천구',
#  '영등포구',
#  '서대문구',
#  '성동구',
#  '용산구',
#  '용산구',
#  '양천구',
#  '성동구',
#  '영등포구',
#  '중구',
#  '중구',
#  '중구',
#  '중구',
#  '용산구',
#  '은평구',
#  '양천구',
#  '양천구',
#  '양천구',
#  '용산구',
#  '은평구',
#  '영등포구',
#  '송파구',
#  '은평구',
#  '양천구',
#  '양천구',
#  '서대문구',
#  '양천구',
#  '은평구',
#  '성동구',
#  '서초구',
#  '용산구',
#  '서대문구',
#  '종로구',
#  '은평구',
#  '성동구',
#  '은평구',
#  '용산구',
#  '성북구',
#  '송파구',
#  '성동구',
#  '영등포구',
#  '성동구',
#  '성동구',
#  '서대문구',
#  '종로구',
#  '중구',
#  '성동구',
#  '성동구',
#  '중구',
#  '용산구',
#  '용산구',
#  '양천구',
#  '영등포구',
#  '노원구',
#  '서대문구',
#  '금천구',
#  '구로구',
#  '동대문구',
#  '구로구',
#  '구로구',
#  '성북구',
#  '강동구',
#  '중구',
#  '중구',
#  '중구',
#  '종로구',
#  '중구',
#  '강서구',
#  '은평구',
#  '은평구',
#  '은평구',
#  '광진구',
#  '성북구',
#  '관악구',
#  '양천구',
#  '서초구',
#  '강서구',
#  '양천구',
#  '도봉구',
#  '노원구',
#  '은평구',
#  '관악구',
#  '구로구',
#  '영등포구',
#  '성동구',
#  '동작구',
#  '관악구',
#  '강북구',
#  '강동구',
#  '서대문구',
#  '성동구',
#  '동작구',
#  '은평구',
#  '강북구',
#  '금천구',
#  '강남구',
#  '양천구',
#  '광진구',
#  '구로구',
#  '구로구',
#  '종로구',
#  '중구',
#  '양천구',
#  '동대문구',
#  '서초구',
#  '강북구',
#  '서대문구',
#  '마포구',
#  '광진구',
#  '영등포구',
#  '동작구',
#  '구로구',
#  '서대문구',
#  '노원구',
#  '동작구',
#  '강동구',
#  '광진구',
#  '광진구',
#  '종로구',
#  '종로구',
#  '송파구',
#  '강남구',
#  '강서구',
#  '구로구',
#  '중구',
#  '동대문구',
#  '도봉구',
#  '영등포구',
#  '성북구',
#  '동대문구',
#  '노원구',
#  '강남구',
#  '송파구',
#  '서대문구',
#  '광진구',
#  '노원구',
#  '금천구',
#  '관악구',
#  '영등포구',
#  '노원구',
#  '성북구',
#  '동작구',
#  '은평구',
#  '강서구',
#  '구로구',
#  '노원구',
#  '강서구',
#  '강남구',
#  '영등포구',
#  '노원구',
#  '노원구',
#  '성동구',
#  '용산구',
#  '마포구',
#  '관악구',
#  '구로구',
#  '강서구',
#  '중랑구',
#  '서초구',
#  '은평구',
#  '동작구',
#  '서대문구',
#  '영등포구',
#  '구로구',
#  '성북구',
#  '강남구',
#  '양천구',
#  '양천구',
#  '금천구',
#  '영등포구',
#  '구로구',
#  '종로구',
#  '도봉구',
#  '강동구',
#  '강북구',
#  '양천구',
#  '광진구',
#  '동대문구',
#  '강동구',
#  '서초구',
#  '동대문구',
#  '중랑구',
#  '강서구',
#  '영등포구',
#  '관악구',
#  '광진구',
#  '강북구',
#  '강동구',
#  '광진구',
#  '광진구',
#  '노원구',
#  '송파구',
#  '송파구',
#  '도봉구',
#  '용산구',
#  '강북구',
#  '광진구',
#  '관악구',
#  '광진구',
#  '금천구',
#  '서초구',
#  '노원구',
#  '은평구',
#  '중구',
#  '영등포구',
#  '영등포구',
#  '영등포구',
#  '강서구',
#  '서초구',
#  '서초구',
#  '송파구',
#  '송파구',
#  '중랑구',
#  '동작구',
#  '동작구',
#  '강서구',
#  '강서구',
#  '강서구',
#  '강동구',
#  '영등포구',
#  '양천구',
#  '노원구',
#  '영등포구',
#  '강남구',
#  '종로구',
#  '양천구',
#  '양천구',
#  '노원구',
#  '서대문구',
#  '종로구',
#  '구로구',
#  '중구',
#  '관악구',
#  '서초구',
#  '영등포구',
#  '은평구',
#  '은평구',
#  '송파구',
#  '송파구',
#  '강동구',
#  '서초구',
#  '중구',
#  '강동구',
#  '금천구',
#  '광진구',
#  '영등포구',
#  '중랑구',
#  '영등포구',
#  '강북구',
#  '광진구',
#  '강북구',
#  '금천구',
#  '송파구',
#  '관악구',
#  '성북구',
#  '중구',
#  '강서구',
#  '광진구',
#  '광진구',
#  '광진구',
#  '강서구',
#  '광진구',
#  '은평구',
#  '송파구',
#  '영등포구',
#  '양천구',
#  '성동구',
#  '성동구',
#  '서초구',
#  '서대문구',
#  '양천구',
#  '서초구',
#  '은평구',
#  '서초구',
#  '용산구',
#  '송파구',
#  '은평구',
#  '용산구',
#  '양천구',
#  '서초구',
#  '은평구',
#  '서초구',
#  '영등포구',
#  '송파구',
#  '성북구',
#  '양천구',
#  '성북구',
#  '양천구',
#  '송파구',
#  '양천구',
#  '서초구',
#  '서대문구',
#  '성동구',
#  '은평구',
#  '성동구',
#  '서초구',
#  '양천구',
#  '서대문구',
#  '양천구',
#  '서대문구',
#  '용산구',
#  '양천구',
#  '은평구',
#  '양천구',
#  '은평구',
#  '송파구',
#  '은평구',
#  '용산구',
#  '서대문구',
#  '은평구',
#  '양천구',
#  '성동구',
#  '양천구',
#  '양천구',
#  '은평구',
#  '은평구',
#  '서대문구',
#  '영등포구',
#  '은평구',
#  '서대문구',
#  '서대문구',
#  '은평구',
#  '은평구',
#  '은평구',
#  '성북구',
#  '서대문구',
#  '서초구',
#  '서초구',
#  '용산구',
#  '서초구',
#  '서초구',
#  '은평구',
#  '송파구',
#  '양천구',
#  '성동구',
#  '양천구',
#  '양천구',
#  '서초구',
#  '은평구',
#  '성북구',
#  '종로구',
#  '성동구',
#  '양천구',
#  '송파구',
#  '성북구',
#  '영등포구',
#  '은평구',
#  '서대문구',
#  '양천구',
#  '성북구',
#  '영등포구',
#  '은평구',
#  '서초구',
#  '양천구',
#  '은평구',
#  '성북구',
#  '성북구',
#  '영등포구',
#  '중구',
#  '양천구',
#  '양천구',
#  '은평구',
#  '송파구',
#  '은평구',
#  '양천구',
#  '양천구',
#  '양천구',
#  '서초구',
#  '송파구',
#  ...]

# %%
chicken_w
# Out:
#       개방서비스명    개방서비스아이디  개방자치단체코드                    관리번호     인허가일자  인허가취소일자  \
# 0      일반음식점  07_24_04_P   3110000  3110000-101-1999-06737  19991113      NaN
# 1      일반음식점  07_24_04_P   3180000  3180000-101-2001-14282  20010818      NaN
# 2      일반음식점  07_24_04_P   3010000  3010000-101-2001-13779  20010521      NaN
# 3      일반음식점  07_24_04_P   3000000  3000000-101-2002-11870  20020205      NaN
# 4      일반음식점  07_24_04_P   3210000  3210000-101-2000-15274  20001201      NaN
# ...      ...         ...       ...                     ...       ...      ...
# 13105  일반음식점  07_24_04_P   3120000  3120000-101-2021-00031  20210122      NaN
# 13106  일반음식점  07_24_04_P   3160000  3160000-101-2020-00384  20201208      NaN
# 13107  일반음식점  07_24_04_P   3200000  3200000-101-2020-00626  20201209      NaN
# 13108  일반음식점  07_24_04_P   3060000  3060000-101-2021-00028  20210203      NaN
# 13109  일반음식점  07_24_04_P   3080000  3080000-101-2021-00015  20210122      NaN
#
#        영업상태구분코드  영업상태명  상세영업상태코드 상세영업상태명  ...  보증액  월세액  다중이용업소여부  시설총규모  \
# 0             1  영업/정상         1      영업  ...  NaN  NaN         N  60.28
# 1             1  영업/정상         1      영업  ...  0.0  0.0         N  12.00
# 2             1  영업/정상         1      영업  ...  NaN  NaN         N  28.60
# 3             1  영업/정상         1      영업  ...  NaN  NaN         N  41.87
# 4             1  영업/정상         1      영업  ...  NaN  NaN         N  19.80
# ...         ...    ...       ...     ...  ...  ...  ...       ...    ...
# 13105         1  영업/정상         1      영업  ...  NaN  NaN         N  49.34
# 13106         1  영업/정상         1      영업  ...  NaN  NaN         N  33.00
# 13107         1  영업/정상         1      영업  ...  NaN  NaN         N  62.80
# 13108         1  영업/정상         1      영업  ...  NaN  NaN         N  53.84
# 13109         1  영업/정상         1      영업  ...  NaN  NaN         N  40.00
#
#       전통업소지정번호 전통업소주된음식  홈페이지 Unnamed: 47   지역구    동이름
# 0          NaN      NaN   NaN         NaN   은평구    갈현동
# 1          NaN      NaN   NaN         NaN  영등포구  양평동3가
# 2          NaN      NaN   NaN         NaN    중구   필동2가
# 3          NaN      NaN   NaN         NaN   종로구    당주동
# 4          NaN      NaN   NaN         NaN   서초구    우면동
# ...        ...      ...   ...         ...   ...    ...
# 13105      NaN      NaN   NaN         NaN  서대문구   남가좌동
# 13106      NaN      NaN   NaN         NaN   구로구    오류동
# 13107      NaN      NaN   NaN         NaN   관악구    신림동
# 13108      NaN      NaN   NaN         NaN   중랑구    상봉동
# 13109      NaN      NaN   NaN         NaN   강북구    수유동
#
# [13110 rows x 49 columns]

# %%
chicken_w_seo = chicken_w[chicken_w['지역구']=='서대문구']

# %%
#동별 치킨집 개수

chicken_count = chicken_w_seo['동이름'].value_counts()
chicken_count = chicken_count.to_dict()

label = list(chicken_count.keys())
size = list(chicken_count.values())

# %%
plt.figure(figsize=(8,6))
squarify.plot(sizes=size, label=label)
plt.title('서대문구 동별 치킨집 트리맵')
plt.show()
# Out:
# <Axes: >
# Text(0.5, 1.0, '서대문구 동별 치킨집 트리맵')

# %%
# Out:
# {'구로구': 783,
#  '마포구': 745,
#  '영등포구': 730,
#  '관악구': 694,
#  '중랑구': 663,
#  '광진구': 650,
#  '강서구': 625,
#  '강동구': 605,
#  '노원구': 586,
#  '동대문구': 570,
#  '은평구': 554,
#  '송파구': 536,
#  '양천구': 513,
#  '성북구': 501,
#  '강북구': 495,
#  '금천구': 479,
#  '서초구': 472,
#  '강남구': 436,
#  '도봉구': 431,
#  '동작구': 409,
#  '서대문구': 400,
#  '성동구': 355,
#  '중구': 329,
#  '종로구': 294,
#  '용산구': 255}

# %%
#구별 치킨집 개수

chicken_whole =  chicken_w['지역구'].value_counts().to_dict()

label = list(chicken_whole.keys())
size = list(chicken_whole.values())

plt.figure(figsize=(8,6))
squarify.plot(sizes=size, label=label)
plt.title('서울 구별 치킨 트리맵')


plt.show()
# Out:
# <Axes: >
# Text(0.5, 1.0, '서울 구별 치킨 트리맵')

# %%
'''
todo:
1.지역구별 치킨 집 회귀선 그리고 이상치 찾아보기
2.지역별로 폐업률 높은곳 찾아보기
3.좌표정보로 지도에 찍어보기
'''
